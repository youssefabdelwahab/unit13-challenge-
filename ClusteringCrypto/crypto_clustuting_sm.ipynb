# %%
pip install -U altair
# Out:
# Requirement already satisfied: altair in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.1.0)
# Requirement already satisfied: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.3)
# Requirement already satisfied: pandas>=0.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.1.5)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.19.5)
# Requirement already satisfied: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.11.3)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (49.6.0.post20210108)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (3.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
import sagemaker 
import sagemaker.amazon.common as smac 
from sagemaker.predictor import csv_serializer , json_deserializer
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3
import io
import numpy as np
import os

# %%
# Alternatively, use the provided csv file:
# file_path = Path("Resources/crypto_data.csv")
crypto_df = pd.read_csv('Data/crypto_data (1).csv')
# Create a DataFrame
crypto_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
crypto_df = crypto_df[crypto_df.IsTrading == True]

# %%
crypto_df = crypto_df.drop(['IsTrading'] , axis = 1)

# %%
crypto_df = crypto_df.dropna()

# %%
crypto_df = crypto_df.drop(crypto_df[crypto_df['TotalCoinsMined'] == 0].index)

# %%
unamed = pd.DataFrame(crypto_df['Unnamed: 0'])

# %%
coin_name_df = pd.DataFrame(crypto_df['CoinName'])

# %%
coin_name_df.set_index(crypto_df.index)
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [533 rows x 1 columns]

# %%
crypto_df = crypto_df.drop(['CoinName', 'Unnamed: 0'] , axis = 1)

# %%
X = pd.get_dummies(data = crypto_df , columns = ['Algorithm' , 'ProofType'])

# %%
scaler = StandardScaler()
scaler.fit(X)
crypto_scaled = scaler.transform(X)

# %%
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_scaled)

# %%
pca_df = pd.DataFrame(data = crypto_pca , columns = ['pca1' , 'pca2' , 'pca3'])

# %%
bucket = 'sagemaker-20210323-1830'

prefix = 'crypto-kmeans-classifier'

role = get_execution_role()

# %%
buf = io.BytesIO()
vectors = np.array(pca_df).astype('float32')
smac.write_numpy_to_dense_tensor(buf , vectors)
buf.seek(0)
# Out:
# 0

# %%
key = 'non_linear.data'
boto3.resource('s3').Bucket(bucket).Object(
    os.path.join(prefix , 'train' , key) 
).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket , prefix , key)
print('Training data uploaded to {}'.format(s3_train_data))
# Out:
# Training data uploaded to s3://sagemaker-20210323-1830/crypto-kmeans-classifier/train/non_linear.data

# %%
from sagemaker import KMeans

# %%
inertia = []
g = list(range(2, 10))



# Calculate the inertia for the range of k values
for i in g: 
    Kmodel = KMeans( role = role, k = i , train_instance_count=1,
                train_instance_type='ml.c4.xlarge',)
    Kmodel.fit(Kmodel.record_set(vectors))
    inertia.append(Kmodel.inertia_)
    

# Create the Elbow Curve using hvPlot
elbow_data = {'k' :k , 'inertia': inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.altair(x= 'k' , y= 'inertia', xticks = g , title = 'Elbow Curve')
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-03-24 01:40:37 Starting - Starting the training job.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1963383d0ba4> in <module>
#       8     Kmodel = KMeans( role = role, k = i , train_instance_count=1,
#       9                 train_instance_type='ml.c4.xlarge',)
# ---> 10     Kmodel.fit(Kmodel.record_set(vectors))
#      11     inertia.append(Kmodel.inertia_)
#      12
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/amazon/amazon_estimator.py in fit(self, records, mini_batch_size, wait, logs, job_name, experiment_config)
#     240         )
#     241         if wait:
# --> 242             self.latest_training_job.wait(logs=logs)
#     243
#     244     def record_set(self, train, labels=None, channel="train", encrypt=False):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1589         # If logs are requested, call logs_for_jobs.
#    1590         if logs != "None":
# -> 1591             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1592         else:
#    1593             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3598                 break
#    3599
# -> 3600             time.sleep(poll)
#    3601
#    3602             if state == LogState.JOB_COMPLETE:
#
# KeyboardInterrupt:

# %%
sess = sagemaker.Session()

# %%
model = KMeans(role = role, k = 4 , train_instance_count=1,
                train_instance_type='ml.c4.xlarge',output_path='s3://{}/{}/output'.format(bucket , prefix),sagemaker_session = sess)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
model.fit(model.record_set(vectors))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-03-24 01:41:20 Starting - Starting the training job...
# 2021-03-24 01:41:43 Starting - Launching requested ML instancesProfilerReport-1616550080: InProgress
# ......
# 2021-03-24 01:42:43 Starting - Preparing the instances for training.........
# 2021-03-24 01:44:16 Downloading - Downloading input data...
# 2021-03-24 01:44:49 Training - Training image download completed. Training in progress.
# 2021-03-24 01:44:49 Uploading - Uploading generated training model.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/24/2021 01:44:47 INFO 140176667305344] Reading default configuration from /opt/amazon/lib/python3.6/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [03/24/2021 01:44:47 INFO 140176667305344] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '3', 'k': '4', 'force_dense': 'True'}
# [03/24/2021 01:44:47 INFO 140176667305344] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '3', 'k': '4'}
# [03/24/2021 01:44:47 WARNING 140176667305344] Loggers have already been setup.
# Process 1 is a worker.
# [03/24/2021 01:44:47 INFO 140176667305344] Using default worker.
# [03/24/2021 01:44:47 INFO 140176667305344] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [03/24/2021 01:44:47 INFO 140176667305344] Create Store: local
# [03/24/2021 01:44:47 INFO 140176667305344] nvidia-smi took: 0.02521967887878418 secs to identify 0 gpus
# [03/24/2021 01:44:47 INFO 140176667305344] Number of GPUs being used: 0
# [03/24/2021 01:44:47 INFO 140176667305344] Checkpoint loading and saving are disabled.
# [03/24/2021 01:44:47 INFO 140176667305344] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '3', 'k': '4'}
# [03/24/2021 01:44:47 INFO 140176667305344] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [03/24/2021 01:44:47 INFO 140176667305344] Number of GPUs being used: 0
# [03/24/2021 01:44:47 INFO 140176667305344] number of center slices 1
# [03/24/2021 01:44:47 WARNING 140176667305344] Batch size 5000 is bigger than the first batch data. Effective batch size used to initialize is 533
# #metrics {"StartTime": 1616550287.68305, "EndTime": 1616550287.6831172, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 533.0, "count": 1, "min": 533, "max": 533}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 533.0, "count": 1, "min": 533, "max": 533}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 533.0, "count": 1, "min": 533, "max": 533}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# [2021-03-24 01:44:47.683] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 26, "num_examples": 1, "num_bytes": 19188}
# [2021-03-24 01:44:47.772] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 87, "num_examples": 1, "num_bytes": 19188}
# [03/24/2021 01:44:47 INFO 140176667305344] processed a total of 533 examples
# [03/24/2021 01:44:47 INFO 140176667305344] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1616550287.6836917, "EndTime": 1616550287.7733839, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1066.0, "count": 1, "min": 1066, "max": 1066}, "Total Batches Seen": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Max Records Seen Between Resets": {"sum": 533.0, "count": 1, "min": 533, "max": 533}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 533.0, "count": 1, "min": 533, "max": 533}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# [03/24/2021 01:44:47 INFO 140176667305344] #throughput_metric: host=algo-1, train throughput=5931.624515440886 records/second
# [03/24/2021 01:44:47 WARNING 140176667305344] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/24/2021 01:44:47 INFO 140176667305344] shrinking 40 centers into 4
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #0. Current mean square distance 0.519320
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #1. Current mean square distance 0.528561
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #2. Current mean square distance 0.519320
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #3. Current mean square distance 0.439114
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #4. Current mean square distance 0.438333
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #5. Current mean square distance 0.519320
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #6. Current mean square distance 0.569807
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #7. Current mean square distance 0.439114
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #8. Current mean square distance 0.438333
# [03/24/2021 01:44:47 INFO 140176667305344] local kmeans attempt #9. Current mean square distance 0.545898
# [03/24/2021 01:44:47 INFO 140176667305344] finished shrinking process. Mean Square Distance = 0
# [03/24/2021 01:44:47 INFO 140176667305344] #quality_metric: host=algo-1, train msd <loss>=0.43833303451538086
# [03/24/2021 01:44:47 INFO 140176667305344] compute all data-center distances: inner product took: 60.5250%, (0.057845 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] collect from kv store took: 7.2106%, (0.006891 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] splitting centers key-value pair took: 7.1006%, (0.006786 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] gradient: cluster center took: 5.9760%, (0.005711 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] gradient: one_hot took: 4.4482%, (0.004251 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] predict compute msd took: 4.4480%, (0.004251 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] compute all data-center distances: point norm took: 4.2881%, (0.004098 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] batch data loading with context took: 3.3032%, (0.003157 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] update state and report convergance took: 1.9690%, (0.001882 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] gradient: cluster size  took: 0.2994%, (0.000286 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] update set-up time took: 0.2522%, (0.000241 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] compute all data-center distances: center norm took: 0.1609%, (0.000154 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] predict minus dist took: 0.0190%, (0.000018 secs)
# [03/24/2021 01:44:47 INFO 140176667305344] TOTAL took: 0.09557151794433594
# [03/24/2021 01:44:47 INFO 140176667305344] Number of GPUs being used: 0
# #metrics {"StartTime": 1616550287.6561892, "EndTime": 1616550287.9191785, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 21.4383602142334, "count": 1, "min": 21.4383602142334, "max": 21.4383602142334}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 89.45345878601074, "count": 1, "min": 89.45345878601074, "max": 89.45345878601074}, "_shrink.time": {"sum": 141.4661407470703, "count": 1, "min": 141.4661407470703, "max": 141.4661407470703}, "finalize.time": {"sum": 143.6443328857422, "count": 1, "min": 143.6443328857422, "max": 143.6443328857422}, "model.serialize.time": {"sum": 1.7023086547851562, "count": 1, "min": 1.7023086547851562, "max": 1.7023086547851562}}}
#
# [03/24/2021 01:44:47 INFO 140176667305344] Test data is not provided.
# #metrics {"StartTime": 1616550287.9192815, "EndTime": 1616550287.9195743, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 14.481067657470703, "count": 1, "min": 14.481067657470703, "max": 14.481067657470703}, "totaltime": {"sum": 333.04357528686523, "count": 1, "min": 333.04357528686523, "max": 333.04357528686523}}}
#
#
# 2021-03-24 01:45:04 Completed - Training job completed
# Training seconds: 41
# Billable seconds: 41

# %%
predictor = model.deploy(initial_instance_count=1, 
                                 instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------------------!

# %%
result=  predictor.predict(vectors)

# %%
cluster_labels = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]

# %%
pca_df['class'] = cluster_labels

# %%
pca_df.head()
# Out:
#        pca1      pca2      pca3  class
# 0 -0.328107  0.963895 -0.410571    0.0
# 1 -0.311388  0.964038 -0.411076    0.0
# 2  2.318312  1.673575 -0.482046    2.0
# 3 -0.146341 -1.268227  0.169577    1.0
# 4 -0.157106 -1.997624  0.296731    1.0

# %%
crypto_df['ye'] = unamed

# %%
crypto_df = crypto_df.set_index('ye')

# %%
clustered_df = pd.DataFrame(crypto_df)

# %%
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# ye
# 42      Scrypt   PoW/PoS     4.199995e+01              42
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337       X13   PoW/PoS     2.927942e+10    314159265359
# BTC    SHA-256       PoW     1.792718e+07        21000000
# ETH     Ethash       PoW     1.076842e+08               0

# %%
req_index = clustered_df.index

# %%
clustered_df = clustered_df.reset_index()

# %%
coin_name_df = coin_name_df.reset_index()

# %%
df_4 = pd.merge(clustered_df, pca_df.iloc[:,0:3], left_index = True , right_index = True)
df_4.head()
# Out:
#      ye Algorithm ProofType  TotalCoinsMined TotalCoinSupply      pca1  \
# 0    42    Scrypt   PoW/PoS     4.199995e+01              42 -0.328107
# 1   404    Scrypt   PoW/PoS     1.055185e+09       532000000 -0.311388
# 2  1337       X13   PoW/PoS     2.927942e+10    314159265359  2.318312
# 3   BTC   SHA-256       PoW     1.792718e+07        21000000 -0.146341
# 4   ETH    Ethash       PoW     1.076842e+08               0 -0.157106
#
#        pca2      pca3
# 0  0.963895 -0.410571
# 1  0.964038 -0.411076
# 2  1.673575 -0.482046
# 3 -1.268227  0.169577
# 4 -1.997624  0.296731

# %%
df_5 = pd.merge( df_4 , coin_name_df ,left_index= True, right_index= True)
df_5.head()
# Out:
#      ye Algorithm ProofType  TotalCoinsMined TotalCoinSupply      pca1  \
# 0    42    Scrypt   PoW/PoS     4.199995e+01              42 -0.328107
# 1   404    Scrypt   PoW/PoS     1.055185e+09       532000000 -0.311388
# 2  1337       X13   PoW/PoS     2.927942e+10    314159265359  2.318312
# 3   BTC   SHA-256       PoW     1.792718e+07        21000000 -0.146341
# 4   ETH    Ethash       PoW     1.076842e+08               0 -0.157106
#
#        pca2      pca3  index   CoinName
# 0  0.963895 -0.410571      0    42 Coin
# 1  0.964038 -0.411076      2    404Coin
# 2  1.673575 -0.482046      5  EliteCoin
# 3 -1.268227  0.169577      7    Bitcoin
# 4 -1.997624  0.296731      8   Ethereum

# %%
clustered_df_final = pd.merge(df_5 , pca_df.iloc[:,3] , left_index = True , right_index = True)
clustered_df_final.head()
clustered_df_final = clustered_df_final.set_index('ye')
clustered_df_final = clustered_df_final.drop(['index'] , axis = 1)
clustered_df_final.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined TotalCoinSupply      pca1      pca2  \
# ye
# 42      Scrypt   PoW/PoS     4.199995e+01              42 -0.328107  0.963895
# 404     Scrypt   PoW/PoS     1.055185e+09       532000000 -0.311388  0.964038
# 1337       X13   PoW/PoS     2.927942e+10    314159265359  2.318312  1.673575
# BTC    SHA-256       PoW     1.792718e+07        21000000 -0.146341 -1.268227
# ETH     Ethash       PoW     1.076842e+08               0 -0.157106 -1.997624
#
#           pca3   CoinName  class
# ye
# 42   -0.410571    42 Coin    0.0
# 404  -0.411076    404Coin    0.0
# 1337 -0.482046  EliteCoin    2.0
# BTC   0.169577    Bitcoin    1.0
# ETH   0.296731   Ethereum    1.0

# %%
alt.Chart(clustered_df_final).mark_circle(size=60).encode(
    x='pca1',
    y='pca2',
    color='class',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
).interactive()
# Out:
# alt.Chart(...)

# %%
from sklearn.preprocessing  import MinMaxScaler
min_max_scaler = MinMaxScaler()
clustered_df_final[['TotalCoinsMined' , 'TotalCoinSupply']] = min_max_scaler.fit_transform(clustered_df_final[['TotalCoinsMined' , 'TotalCoinSupply']])

# %%
alt.Chart(clustered_df_final).mark_circle(size=60).encode(
    x='TotalCoinsMined',
    y='TotalCoinSupply',
    color='class',
    tooltip=['CoinName', 'Algorithm', 'TotalCoinsMined', 'TotalCoinSupply']
).interactive()
# Out:
# alt.Chart(...)
